# %%
# !pip install langchain_community
# !pip install langchain_chroma
# !pip install langchain_groq
# !pip install "unstructured[pdf]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 87.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 129.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 81.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
# ...

# %%
import os
#from langchain.document_loaders import UnstructuredFileLoader #old import not working
from langchain_unstructured import UnstructuredLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_groq import ChatGroq
from langchain_classic.chains import RetrievalQA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2469/205397719.py in <cell line: 0>()
#       1 import os
#       2 #from langchain.document_loaders import UnstructuredFileLoader #old import not working
# ----> 3 from langchain_unstructured import UnstructuredLoader
#       4 from langchain_text_splitters import CharacterTextSplitter
#       5 from langchain_community.embeddings import HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'langchain_unstructured'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
os.environ["GROQ_API_KEY"]="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"

# %%
import os
from langsmith import Client

os.environ["GROQ_API_KEY"]="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"

os.environ["LANGCHAIN_API_KEY"]="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"

os.environ["LANGCHAIN_TRACING_V2"]="true"

os.environ["LANGCHAIN_PROJECT"]="RAG-UPGRADE-PROJECT"
print("Langchain tracing Enabled Successfully")
# Out:
# Langchain tracing Enabled Successfully

# %%
import requests
url="https://www.hkdca.com/wp-content/uploads/2025/03/ai-interview-questions-intellipaat.pdf"

response = requests.get(url)

with open('ai-interview-questions-intellipaat.pdf', 'wb') as f:
    f.write(response.content)

# %%
loader = UnstructuredFileLoader("ai-interview-questions-intellipaat.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2469/2130258900.py in <cell line: 0>()
# ----> 1 loader = UnstructuredFileLoader("ai-interview-questions-intellipaat.pdf")
#
# NameError: name 'UnstructuredFileLoader' is not defined

# %%
# !pip install unstructured
# !pip install langchain-unstructured

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader("ai-interview-questions-intellipaat.pdf")

# %%
docs = loader.load()
# Out:
# WARNING:unstructured:No languages specified, defaulting to English.

# %%
from langchain_unstructured import UnstructuredLoader
from langchain_text_splitters import CharacterTextSplitter

loader = UnstructuredLoader("ai-interview-questions-intellipaat.pdf")
docs = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)
# Out:
# WARNING:unstructured:No languages specified, defaulting to English.

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community.vectorstores.utils import filter_complex_metadata

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Apply filter_complex_metadata to the texts to remove unsupported metadata types
filtered_texts_for_chroma = filter_complex_metadata(texts)

db = Chroma.from_documents(filtered_texts_for_chroma, embeddings)
# Out:
# /tmp/ipykernel_2469/1932945199.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import HuggingFaceEmbeddings
# /tmp/ipykernel_2469/1932945199.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
from langchain_groq import ChatGroq
from langchain_classic.chains import RetrievalQA

llm = ChatGroq(model_name='llama-3.1-8b-instant')
rqa = RetrievalQA.from_chain_type(llm=llm, chain_type='stuff', retriever=db.as_retriever(), return_source_documents=True)

# %%
query = "What are some common AI interview questions?"
response = rqa.invoke(query)
print(response['result'])
# Out:
# Here are some common AI interview questions:
#
# 1. **Explain the difference between supervised, unsupervised, and reinforcement learning.**
#    - This question assesses your understanding of the fundamental concepts in machine learning.
#
# 2. **How does a neural network work?**
#    - This question evaluates your knowledge of neural networks and their applications.
#
# 3. **What is the difference between a perceptron and a multilayer perceptron?**
#    - This question checks your understanding of basic neural network architectures.
#
# 4. **Can you explain the concept of overfitting and how to prevent it?**
#    - This question evaluates your knowledge of common machine learning challenges and techniques to address them.
#
# 5. **What is the difference between a decision tree and a random forest?**
#    - This question assesses your understanding of decision-making algorithms and ensemble methods.
#
# 6. **Can you describe the process of training a model using backpropagation?**
# ...

# %%
import gradio as gr

# Chat Function
def chatbot_response(question):

    try:
        response = rqa.invoke({"query": question})

        answer = response["result"]

        sources = []

        for doc in response["source_documents"]:
            if "source" in doc.metadata:
                sources.append(doc.metadata["source"])

        source_text = "\n".join(list(set(sources)))

        final_response = f"""
{answer}

-------------------
Source:
{source_text}
"""

        return final_response

    except Exception as e:
        return f"Error: {str(e)}"


# Gradio UI
demo = gr.Interface(
    fn=chatbot_response,
    inputs=gr.Textbox(
        lines=2,
        placeholder="Ask questions from your PDF..."
    ),
    outputs="text",
    title="RAG PDF Chatbot",
    description="LLMOps Project using LangChain + Groq + ChromaDB + Gradio",
    theme="soft"
)

demo.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://7479f895d193be93a9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7479f895d193be93a9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Using existing dataset file at: .gradio/flagged/dataset1.csv

# %%
#!pip install --upgrade langchain langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 56.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.4/236.4 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.1
#     Uninstalling langgraph-1.2.1:
#       Successfully uninstalled langgraph-1.2.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.1
#     Uninstalling langchain-1.3.1:
#       Successfully uninstalled langchain-1.3.1
# ...

# %%
#!pip install sentence-transformers
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
# ...
